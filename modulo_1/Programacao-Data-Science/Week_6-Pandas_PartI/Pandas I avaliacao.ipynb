# %% [markdown]
# # <font color="blue"> MBA em Ciência de Dados</font>
# # <font color="blue">Programação para Ciência de Dados</font>
#
# ## <font color="blue">Pandas Parte I - Avaliação</font>
# **Material Produzido por Luis Gustavo Nonato**<br>
# **Cemeai - ICMC/USP São Carlos**
# ---

# %% [markdown]
# As questões a seguir farão uso do arquivo <font style="font-family: monaco">WorldCupMatches.csv</font>, disponível para download no moodle. Baixe o arquivo no seu diretório de trabalho para responder as questões.
#
# O arquivo <font style="font-family: monaco">WorldCupMatches.csv</font> contém informações sobre todas as partidas de copas do mundo entre 1930 e 2014, ou seja, cada linha no arquivo corresponde a uma partida de futebol em copa do mundo.
#
# Algumas das colunas que serão importantes para resolver as questões são:
# - __Year__: indica o ano da copa
# - __Stage__: em qual fase da copa a partida aconteceu
# - __HomeTeamName__: nome do time anfitrião da partida
# - __AwayTeamName__: nome do time adversário na partida
# - __Attendance__: número de espectadores da partida
# - __Stadium__: estádio onde a partida foi realizada

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Exercício 1)
# Leia o arquivo <font style="font-family: monaco">WorldCupMatches.csv</font>, armazene em uma variável DataFrame  chamada `copa_partidas`. Quantas colunas o DataFrame possui e quais as colunas cujo rótulo possui o menor número de caracteres?
#
# a) 17, 'Round', 'Match'<br>
# b) 18, ['Stage', 'Stadi']<br>
# c) 20, ['Year', 'City']<br>
# d) 22, ['Home','WinC']

# %%
# SOLUÇÃO
copa_partidas = pd.read_csv('WorldCupMatches.csv')
print(f'The number of columns is {len(copa_partidas.columns)}')
columnNames = np.array(copa_partidas.columns.values)
sortedColumns = np.argsort([len(columnName) for columnName in copa_partidas.columns.values])
print(columnNames[sortedColumns])
# Out:
# The number of columns is 20
# ['Year' 'City' 'Stage' 'Stadium' 'MatchID' 'RoundID' 'Referee' 'Datetime'
#  'Assistant2' 'Attendance' 'Assistant1' 'HomeTeamName' 'AwayTeamName'
#  'WinConditions' 'AwayTeamGoals' 'HomeTeamGoals' 'HomeTeamInitials'
#  'AwayTeamInitials' 'HalfTimeHomeGoals' 'HalfTimeAwayGoals']

# %% [markdown]
# ### Exercício 2)
# O comando abaixo extrai quais são as 'strings' contidas na coluna `Stage`:
# ```python
# copa_partidas['Stage'].unique()
# ```
# Dentre as strings resultantes, 'Semi-finals' indica que a linha corresponde a uma partida de semi-final de uma copa.
#
# Utilizando o método <font color='blue'>query</font>, encontre as linhas contendo as partidas de semi-final das copas. Construa uma lista contendo os nomes dos times que disputaram a semi-final da copa de 1986.
#
# Os nomes que aparecem na lista construída são:
#
# a) ['France', 'Argentina', 'Germany FR', 'Belgium']<br>
# b) ['Franca', 'Argentina', 'Alemanha', 'Belgica']<br>
# c) ['France', 'Argentina', 'Germany', 'Belgium']<br>
# c) ['France', 'Argentina', 'Peru', 'Belgium']<br>
#
# __DICA:__ Utilize o método <font color='blue'>query</font> duas vezes, a primeira para obter um DataFrame com os semi-finalistas e a segunda para obter um DataFrame com os semi-finalistas da copa de 1986. Os nomes dos semi-finalistas estão nas colunas `HomeTeamNam` e `AwayTeamName`.

# %%
# SOLUÇÃO

semi_final_results = copa_partidas.query('Stage == "Semi-finals" & Year==1986')
teams = np.hstack((semi_final_results['HomeTeamName'].values, semi_final_results['AwayTeamName'].values))
print(f"The teams who played in the 1986 semi-finals were: {teams}")
# Out:
# The teams who played in the 1986 semi-finals were: ['France' 'Argentina' 'Germany FR' 'Belgium']

# %% [markdown]
# ### Exercício 3)
# Quantas vezes o Brasil jogou contra a Argentina em copas do mundo?
#
# a) 7<br>
# b) 6<br>
# c) 5<br>
# d) 4
#
# __Dica:__ Utilize o método <font color='blue'>query</font> combinando <font color='blue'>&</font> (AND) e <font color='blue'>|</font> (OR)

# %%
# SOLUÇÃO
brazil_vs_arg_query = copa_partidas.query("(HomeTeamName=='Brazil' & AwayTeamName=='Argentina') | (HomeTeamName=='Argentina' & AwayTeamName=='Brazil')")
print(len(brazil_vs_arg_query))
print(brazil_vs_arg_query)
# Out:
# 4
#      Year              Datetime        Stage  \
# 260  1974  30 Jun 1974 - 16:00       Group A
# 301  1978  18 Jun 1978 - 19:15       Group B
# 350  1982  02 Jul 1982 - 17:15       Group 3
# 450  1990  24 Jun 1990 - 17:00   Round of 16
#
#                                          Stadium        City HomeTeamName  \
# 260                         Niedersachsenstadion    Hanover     Argentina
# 301  Arroyito - Estadio Dr. Lisandro de la Torre    Rosario     Argentina
# 350                                       Sarria  Barcelona     Argentina
# 450                            Stadio delle Alpi      Turin        Brazil
#
#      HomeTeamGoals  AwayTeamGoals AwayTeamName WinConditions  Attendance  \
# 260              1              2       Brazil                   39400.0
# 301              0              0       Brazil                   37326.0
# 350              1              3       Brazil                   44000.0
# 450              0              1    Argentina                   61381.0
#
#      HalfTimeHomeGoals  HalfTimeAwayGoals                    Referee  \
# 260                  1                  1         LORAUX Vital (BEL)
# 301                  0                  0       PALOTAI Karoly (HUN)
# 350                  0                  1  RUBIO VAZQUEZ Mario (MEX)
# 450                  0                  0         QUINIOU Joel (FRA)
#
#                             Assistant1                Assistant2  RoundID  \
# 260                NDIAYE Birame (SEN)         TAYLOR John (ENG)      263
# 301               LINEMAYR Erich (AUT)        PROKOP Adolf (GDR)      279
# 350  ARISTIZABAL MURCIA Gilberto (COL)       CASTRO Gaston (CHI)      294
# 450                SPIRIN Alexey (RUS)  PAIRETTO Pierluigi (ITA)      323
#
#      MatchID HomeTeamInitials AwayTeamInitials
# 260     1945              ARG              BRA
# 301     2196              ARG              BRA
# 350      750              ARG              BRA
# 450       25              BRA              ARG

# %% [markdown]
# ### Exercício 4)
# Qual foi a partida em copa do mundo com o maior número de espectadores?
#
# a) Mexico X Paraguay em 1986<br>
# b) Uruguay X Brazil em 1950<br>
# c) Brazil X Sweden em 1950<br>
# d) Argentina X England em 1986
#
# __DICA:__ Ordene o DataFrame pela coluna `Attendance`

# %%
# SOLUÇÃO
partida_max_att = copa_partidas.sort_values(by='Attendance').iloc[-1]
print(partida_max_att)
# Out:
# Year                                                      1950
# Datetime                                  16 Jul 1950 - 15:00
# Stage                                                  Group 6
# Stadium              Maracan� - Est�dio Jornalista M�rio Filho
# City                                           Rio De Janeiro
# HomeTeamName                                           Uruguay
# HomeTeamGoals                                                2
# AwayTeamGoals                                                1
# AwayTeamName                                            Brazil
# WinConditions
# Attendance                                              173850
# HalfTimeHomeGoals                                            0
# HalfTimeAwayGoals                                            0
# Referee                                    READER George (ENG)
# Assistant1                                  ELLIS Arthur (ENG)
# Assistant2                               MITCHELL George (SCO)
# RoundID                                                    209
# MatchID                                                   1190
# HomeTeamInitials                                           URU
# AwayTeamInitials                                           BRA
# Name: 74, dtype: object

# %% [markdown]
# ### Exercício 5)
# Qual foi o estádio com o maior número de partidas?
#
# a) Nacional<br>
# b) Jalisco<br>
# c) Maracana<br>
# d) Estadio Azteca
#
# __Dica:__ Construa um dicionário onde a chave é o nome do estádio e o valor do número de partidas disputadas naquele estádio. Busque pela tupla (chave,valor) onde valor é máximo.

# %%
# SOLUÇÃO
print(copa_partidas['Stadium'].value_counts().index.values[0], copa_partidas['Stadium'].value_counts().values[0])
print(copa_partidas['Stadium'].value_counts().index.values[-1], copa_partidas['Stadium'].value_counts().values[-1])
# Out:
# Estadio Azteca 19
# White City 1
